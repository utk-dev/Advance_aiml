# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib widget
from lab_utils_common import plot_data, sigmoid, dlc
plt.style.use('./deeplearning.mplstyle')

# %%
X_train = np.array([[0.5, 1.5], [1,1], [1.5, 0.5], [3, 0.5], [2, 2], [1, 2.5]])
y_train = np.array([0,0,0,1,1,1])

# %%
fig,ax = plt.subplots(1,1,figsize=(4,4))
plot_data(X_train, y_train, ax)

ax.axis([0,4,0,3.5])
ax.set_xlabel("$x_0$", fontsize=12)
ax.set_ylabel("$x_1$", fontsize=12)
# Out:
# Text(0, 0.5, '$x_1$')
# Canvas(footer_visible=False, header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', …

# %%
def compute_cost_logistic(X,y,w,b):
    m=X.shape[0]
    cost=0.0
    for i in range(m):
        z_i = np.dot(X[i],w)+b
        f_wb_i = sigmoid(z_i)
        cost += (-y[i])*(np.log(f_wb_i)) - (1-y[i])*(np.log(1-f_wb_i))
        
    cost = cost/m
    return cost

# %%
w_tmp = np.array([1,1])
b_tmp = -3
print(compute_cost_logistic(X_train,y_train,w_tmp,b_tmp))
# Out:
# 0.36686678640551745

# %%
x0 = np.arange(0,6)

x1 = 3 - x0
x1_other = 4 - x0

fig,ax = plt.subplots(1,1,figsize=(4,4))
#plotting the decision boundary
ax.plot(x0,x1,c=dlc['dlblue'], label="$b$=-3")
ax.plot(x0,x1_other,c=dlc['dlmagenta'], label="$b$=-4")
ax.axis([0,4,0,4])

#plotting the data
plot_data(X_train, y_train,ax)
ax.axis([0,4,0,4])
ax.set_ylabel('$x_1$', fontsize=12)
ax.set_xlabel('$x_0$', fontsize=12)
plt.legend(loc='upper right')
plt.title('Decision Boundary')
plt.show()
# Out:
# Canvas(footer_visible=False, header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', …

# %% [markdown]
# You can see from this plot that b = -4, w = np.array([1,1]) is a worse model for the training data.

# %%
w_array1 = np.array([1,1])
b_array1 = -3
w_array2 = np.array([1,1])
b_array2 = -4

print(f"Cost Function of array_1: {compute_cost_logistic(X_train,y_train,w_array1,b_array1)}")
print(f"Cost Function of array_2: {compute_cost_logistic(X_train,y_train,w_array2,b_array2)}")
# Out:
# Cost Function of array_1: 0.36686678640551745
# Cost Function of array_2: 0.5036808636748461
