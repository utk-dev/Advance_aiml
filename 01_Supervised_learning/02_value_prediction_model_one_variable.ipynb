# %%
import numpy as np
import matplotlib.pyplot as plt

x_train = np.array([3,5])
y_train = np.array([300,500])

plt.scatter(x_train,y_train, marker='*',c='r')
plt.title('Housing Prices')
plt.ylabel("Price in 1000s of dollars($)")
plt.xlabel("Size(1000 sqft)")
plt.show()

# %%
w = 100
b = 0
print(f"w:{w}")
print(f"b:{b}")
# Out:
# w:100
# b:0

# %%
def compute_model_output(x,w,b):
    m=x.shape[0]
    f_wb = np.zeros(m)
    for i in range(m):
        f_wb[i]=w*x[i] + b
    return f_wb

# %%
tmp_f_wb = compute_model_output(x_train,w,b)

plt.title("Housing Prices")
plt.scatter(x_train, y_train, c='r', marker='*', label="Actual Values")
plt.plot(x_train, tmp_f_wb, c='b', label="Our Prediction")
plt.xlabel("Size(1000 sqfts)")
plt.ylabel("Price in 1000s($)")
plt.legend()
plt.show()

# %%
w = 234.78
b = 123.4567
x_i = 1.2
cost_price = w*x_i + b
print(f"The cost of the house is: {cost_price:.0f} thousand dollars")
# Out:
# The cost of the house is: 405 thousand dollars
